# %% [markdown]
# <a href="https://colab.research.google.com/github/shailymishra/Machine-Learning-Concepts/blob/master/1)_Load_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Load popular datasets and split into train and test
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %matplotlib inline
      
## just copy paste any from the below and use this method in our program
## LOAD, SPLIT, VISUALIZE
## return X_train,y_train,X_test,y_test
def load_data():
  pass

# %%
####
# 1. MNIST
####

if(True):
  ## load directly => sklearn dataset - mnist digit
  digits = load_digits()
  X, y = digits.data, digits.target
  X_train, X_test, y_train, y_test = train_test_split(X, y)
elif(False):
  ### load from a excel  - mnist digit
  df_train = pd.read_csv('mnist_train.csv', sep=",", header=None, nrows=6000)
  X_train = df_train.values[:, 1:]
  y_train = df_train.values[:, [0]]

  df_test = pd.read_csv('mnist_test.csv', sep=",", header=None, skiprows=9000)
  X_test = df_test.values[:, 1:]
  y_test = df_test.values[:, [0]]


# Example digits
fig = plt.figure(figsize=(10,8))
for i in range(10):
    ax = fig.add_subplot(2, 5, i+1)
    plt.imshow(X[i].reshape((8,8)), cmap='gray')
    
plt.show()

# %%
#######
# 1. IRIS
#######

if(True):
  ## SKLEARN dataset
  iris = datasets.load_iris()
  X = iris.data
  y = iris.target
elif(False):
  url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
  # Assign colum names to the dataset
  names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']
  # Read dataset to pandas dataframe
  dataset = pd.read_csv(url, names=names)
  X = dataset.iloc[:, :-1].values
  y = dataset.iloc[:, 4].values

X_train, X_test, y_train, y_test = train_test_split(X, y)


### PLOTING two dimension 
plt.figure(2, figsize=(8, 6))
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.Set1, edgecolor="k")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.show()
